# %% [markdown]
# # <a href="https://miptstats.github.io/courses/ad_fivt.html">Введение в анализ данных</a>
# ## Домашнее задание 1. Простой анализ данных.

# %% [markdown]
# **Правила, <font color="red">прочитайте внимательно</font>:**
#
#
# * Дедлайн см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины. Правила переноса дедлайнов определены в презентации с первого занятия.
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания все участники списывания будут сдавать устный зачет.**
# * Задачи 1 и 2 сдаются в систему Яндекс.Контест. Ссылка на контест в телеграм-боте.
#
#
# **Сдача задачи 3:**
#
# * Выполненную работу нужно отправить телеграм-боту `@miptstats_ds24_bot`. Для начала работы с ботом каждый раз отправляйте `/start`. Дождитесь подтверждения от бота, что он принял файл. Если подтверждения нет, то что-то не так. **Работы, присланные иным способом, не принимаются.**
# * Прислать нужно **ноутбук в формате `ipynb`**.
# * Телеграм не разрешает боту получать файлы более **20 Мб**. Если ваше решение весит больше, *заранее* разделите ноутбук на несколько.
# * Для выполнения задания **используйте этот ноутбук в качестве основы, ничего не удаляя из него**. Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
# * **Код из рассказанных на занятиях ноутбуков** можно использовать без ограничений.
#
# **Перед выполнением задания посмотрите презентацию по выполнению и оформлению домашних заданий с занятия 2.**
#
# ---
#
# **Баллы за задание:**
#
# <b><font color="blue">Легкая часть</font></b> (достаточно на "хор"):
# * Задача 1 &mdash; 10 баллов
# * Задача 2 &mdash; 10 баллов
# * Задача 3 &mdash; 80 баллов
#
#
# Баллы учитываются в <b>обязательной части</b> курса и не влияют на оценку по факультативной части.

# %%
# Bot check

# HW_ID: fpmi_ad1
# Бот проверит этот ID и предупредит, если случайно сдать что-то не то

# Status: final
# Перед отправкой в финальном решении удали "not" в строчке выше
# Так бот проверит, что ты отправляешь финальную версию, а не промежуточную

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid', font_scale=1.3, palette='Set2')

# %% [markdown]
# ### <font color="blue"><i>Легкая часть</i></font>
#
# ### Задача 1.
#
# Условие задачи и сдача в системе Яндекс.Контест. Ссылка на контест в телеграм-боте.

# %% [markdown]
# ---
# ### Задача 2.
#
# Условие задачи и сдача в системе Яндекс.Контест. Ссылка на контест в телеграм-боте.

# %% [markdown]
# ---
# ### Задача 3.

# %% [markdown]
# Титаник был крупнейшим пассажирским судном в 1912—1913 годах. Во время первого рейса затонул в северной Атлантике, столкнувшись с айсбергом в ночь с 14 на 15 апреля 1912 года, при этом погибло 1502 из 2224 пассажиров и членов экипажа. Данные о пассажирах были собраны в таблицы, которые можно скачать с <a href="https://www.kaggle.com/c/titanic/data" target="_blank">Kaggle</a>. Эти данные часто используются в качестве обучающих в анализе данных.

# %% [markdown]
# На дополнительном занятии 10 февраля будет показан простой пример работы с датасетом Титаник. Сейчас ваша задача &mdash; на основе простого анализа предоставленных данных обучить несколько классификаторов для определения выживших, иначе говоря, получить некоторые приближенные правила определения, выжил пассажир или нет, а также сравнить эти правила по качеству приближения.
#
# #### 1. Подготовка данных
#
# Загрузите данные с помощью `pandas`.

# %%
data = pd.read_csv('titanic/train.csv', index_col=0)
df = pd.DataFrame(data)

# %% [markdown]
# Разделите данные по строкам на две части случайным образом в соотношении 7:3. Первую часть мы будем называть *обучающей*, а вторую &mdash; *тестовой*.

# %%
train = df.sample(frac=0.7, random_state=200)
test = df.drop(train.index)

# %% [markdown]
# Из каждой части оставим несколько признаков, с которыми мы будем работать, а также отдельно &mdash; целевой признак. Примените к обеим частям таблицы функцию ниже

# %%
features_columns = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']
target_column = 'Survived'  # Целевой признак

def get_features_and_target(data):
    features = data[features_columns]
    target = data[target_column]
    return features, target

# %%
train_features, train_target = get_features_and_target(train)
test_features, test_target = get_features_and_target(test)

# %% [markdown]
# #### 2. Исследование
#
# **Внимание.** Эта часть задачи должна выполняться *исключительно на обучающих данных*. За использование тестовых данных решение не будет оценено.
#
# Проведите визуальный анализ данных чтобы понять, как различные признаки влияют на целевой. Исследовать можно не целиком обучающие данные, а разделить их на две части по одному из признаков, а далее рассматривать каждую часть отдельно.
#
# *Не забывайте про информативность и эстетичность графиков.*

# %%
with sns.axes_style('whitegrid'):
    plt.figure()
    plt.xlabel('Класс')
    plt.ylabel('Количество выживших')
    plt.xticks([1, 2, 3])
    plt.title('Влияние класса')
    sns.histplot(data=data, x='Pclass', hue='Survived', multiple='stack')

with sns.axes_style('whitegrid'):
    plt.figure()
    plt.xlabel('Пол')
    plt.ylabel('Количество выживших')
    plt.title('Влияние пола')
    sns.histplot(data=data, x='Sex', hue='Survived', multiple='stack')

with sns.axes_style('whitegrid'):
    plt.figure()
    plt.xlabel('Возраст')
    plt.ylabel('Количество выживших')
    plt.title('Влияние возраста')
    sns.histplot(data=data, x='Age', hue='Survived', multiple='stack')

with sns.axes_style('whitegrid'):
    plt.figure()
    plt.xlabel('Количество братьев/сестёр')
    plt.ylabel('Количество выживших')
    plt.title('Влияние братьев/сестёр')
    sns.histplot(data=data, x='SibSp', hue='Survived', multiple='stack')

# %% [markdown]
# - По отношению к общему числу пассажиров одного пола женщин спаслось больше. Вероятность выжить существенно зависит от пола.
# - Вероятность спасения не сильно зависит от возраста, т.к. отношение количества спасённых к общему числу пассажиров данного возраста коллеблется не существенно.
# - Шанс на спасение у 3го класса был мал, у 1го класса - наоборот, самый высокий из всех. Видно также, что большинство людей было в 3м классе. Можно взять в качестве одного из критериев смертности принадлежность 3му классу.

# %% [markdown]
# #### 3. Классификация методом ближайшего соседа
#
# Ранее в контесте вы уже реализовали функцию поиска ближайших соседей. Теперь давайте применим ее для решения нашей текущей задачи.
#
# Реализуйте функцию, которая для каждого объекта тестового набора данных найдет $k$ ближайших соседей из обучающего набора данных, и в качестве ответа возьмет наиболее часто встречающееся значение целевого признака среди найденных соседей. Обратите внимание, что соседей необходимо искать только среди объектов обучающего набора данных.

# %% [markdown]
# - Оставляем только целевые признаки

# %%
features_columns = ['Age', 'Fare']

filtered_train_features = train_features[features_columns]
filtered_features = test_features[features_columns]

# %% [markdown]
# - Пропуски заполняем средними значениями

# %%
filtered_train_features.fillna(value=filtered_train_features.median())
# Out:
#               Age      Fare
# PassengerId
# 660          58.0  113.2750
# 526          40.5    7.7500
# 829          28.0    7.7500
# 754          23.0    7.8958
# 519          36.0   26.0000
# ...           ...       ...
# 825           2.0   39.6875
# 390          17.0   12.0000
# 95           59.0    7.2500
# 827          28.0   56.4958
# 112          14.5   14.4542
#
# [624 rows x 2 columns]

# %% [markdown]
# - Нормируем данные по min-max

# %%
def normalization(features):
    return (features - features.min()) / (features.max() - features.min())

for column in features_columns:
    filtered_features.loc[:, column] = normalization(filtered_features.loc[:, column])
for column in features_columns:
    filtered_train_features.loc[:, column] = normalization(filtered_train_features.loc[:, column])

# %%
def knn(features, train_features, train_target, k=1):
    '''
    Предсказание целевого признака для данных features -- pandas-таблица данных.
    на основе обучающего набора данных train_features, train_target.
    Возвращает pandas.Series с теми же индексами, что и у features.
    Число k -- количество соседей.
    '''

    np_features = features.to_numpy()
    np_train_features = train_features.to_numpy()

    # Считаем матрицу дистанций между всеми тестовыми и всеми тренировочными точками
    distances = np.sqrt(np.sum(np_features ** 2, axis=1)[:, np.newaxis] - 2 * np.sum(np_features[:, :, None] * np_train_features.T[:, :], axis=1) 
                                   + np.sum(np_train_features ** 2, axis=1))
    
    # Находим индексы ближайших k соседей
    nearest_k_indices = np.argsort(distances, axis=1)[:, :k]

    predicted = []
    
    # Находим таргеты по указанным индексам
    for row in nearest_k_indices:
        row_targets = train_target.iloc[row].mode()[0]
        predicted.append(row_targets)

    return pd.Series(predicted, index=features.index)

# %% [markdown]
# Постройте классификатор методом ближайшего соседа, используя только признаки `Age` и `Fare`.
#
# Какую метрику (функцию расстояния) вы при этом используете? Нужно ли предварительно что-то сделать с признаками?

# %% [markdown]
# - Метрика евклидова, данные нормируем, пропуски заполняем средними значениями

# %% [markdown]
# Как меняется результат классификации при другом количестве соседей? Рассмотрите хотя бы три различных нечетных значения количества соседей.

# %%
knn_pred1 = knn(filtered_features, filtered_train_features, train_target, 3)
knn_pred2 = knn(filtered_features, filtered_train_features, train_target, 9)
knn_pred3 = knn(filtered_features, filtered_train_features, train_target, 15)
knn_pred4 = knn(filtered_features, filtered_train_features, train_target, 21)

# %% [markdown]
# - С увеличением количества соседей точность классификации увеличивается (см. тесты ниже).

# %% [markdown]
# Как можно было бы учесть другие признаки? Какие при этом могут возникнуть проблемы?
#
# - Сложности могут возникнуть при учёте дискретных признаков, принимающих только два значения. Тогда для расстояния есть только два варианта - 0 и 1. Ясно, что 0 всегда будет побеждать, класс точка быть отнесена в ошибочную категорию по данному признаку и предсказание исказится
#
# Строить классификатор с другими признаками при этом не нужно.

# %% [markdown]
# #### 4. Классификация логическими правилами
#
# На основе выше проведенного исследования предложите два разных правила в виде решающего дерева, пример которого можете посмотреть в презентации с первой лекции (классификация котиков). Никакие статистические методы использовать не требуется, только логику и графики.
#
# В данной задаче достаточно, если первое дерево будет иметь максимальную глубину 2, а второе &mdash; глубину 1, и при этом не является поддеревом первого. *Примечание*: дерево из одного листа имеет глубину 0.
#
# **Дерево 1:**
#
# 1) Пол: женщина - 1, мужчина - спуск вниз
# 2) Класс: не третий - 1, иначе - 0
#
# **Дерево 2:**
#
# 1) Возраст: <= 35 - 1, иначе - 0
#
# Реализуйте полученные деревья по шаблону

# %%
def tree1(features):
    '''
    Предсказание целевого признака для данных features -- pandas-таблица данных.
    Возвращает pandas.Series с теми же индексами, что и у features.
    '''

    predicted = (features['Sex'] == 'female') | (features['Pclass'] != 3)

    return pd.Series(predicted, index=features.index)

# %%
def tree2(features):
    '''
    Предсказание целевого признака для данных features -- pandas-таблица данных.
    Возвращает pandas.Series с теми же индексами, что и у features.
    '''
    
    conditions = (features['Age'] <= 35)

    return pd.Series(conditions, index=features.index)

# %%
tree_pred1 = tree1(test_features)
tree_pred2 = tree2(test_features)

# %% [markdown]
# #### 5. Качество
#
# Вспомним, что у нас имеется тестовая часть выборки. Самое время ее использовать для того, чтобы оценить, насколько хорошими получились деревья. Предложите какой-нибудь критерий качества.
#
# *Замечание*. Не стоит пытаться искать, какие критерии существуют. В данном случае легко предложить адекватный критерий. Стандартные критерии мы разберем позже, но для начала лучше подумать самостоятельно.
#
# **Критерий:**
#
# - Отношение количества попаданий к общему числу точек
#
# Реализуйте данный критерий по шаблону

# %%
def criteria(target, predicted):
    '''
    Вычисление критерия качества для предсказания predicted, 
    если истинные значения -- target.
    Возвращает одно вещественное число.
    '''
    return np.sum(target == predicted) / len(target)

# %% [markdown]
# Оцените качество построенных ранее моделей (два дерева, kNN), используя предложенный критерий.
#
# *Примечание.* Полученные значения не влияют на оценку по задание. Оценивается только корректность и обоснованность решения, а также графики и выводы.

# %%
print("knn 1 (k = 3):\t", criteria(test_target, knn_pred1))
print("knn 2 (k = 9):\t", criteria(test_target, knn_pred2))
print("knn 3 (k = 15):\t", criteria(test_target, knn_pred3))
print("knn 4 (k = 21):\t", criteria(test_target, knn_pred4))

print("\ntree 1: ", criteria(test_target, tree_pred1))
print("tree 2: ", criteria(test_target, tree_pred2))
# Out:
# knn 1 (k = 3):	 0.6329588014981273
# knn 2 (k = 9):	 0.6704119850187266
# knn 3 (k = 15):	 0.6554307116104869
# knn 4 (k = 21):	 0.6666666666666666
#
# tree 1:  0.6666666666666666
# tree 2:  0.5355805243445693

# %% [markdown]
# Посчитайте значение предложенного ранее критерия качества для метода ближайшего соседа для значений $k$ от 1 до 10. Постройте график зависимости критерия качества от $k$. Как вы можете пояснить полученные результаты?

# %%
k_axis = np.arange(1, 11)
criteria_axis = []
for k in k_axis:
    criteria_axis.append(criteria(test_target, knn(filtered_features, filtered_train_features, train_target, k)))

plt.figure()
plt.plot(k_axis, criteria_axis)
plt.xlabel('Значение k')
plt.ylabel('Критерий качества')
plt.title('Точность предсказания в зависимости от k')
plt.show()

# %%
k_axis = np.arange(1, 51)
criteria_axis = []
for k in k_axis:
    criteria_axis.append(criteria(test_target, knn(filtered_features, filtered_train_features, train_target, k)))

plt.figure()
plt.plot(k_axis, criteria_axis)
plt.xlabel('Значение k')
plt.ylabel('Критерий качества')
plt.title('Точность предсказания в зависимости от k')
plt.show()

# %%
k_axis = np.arange(1, 101)
criteria_axis = []
for k in k_axis:
    criteria_axis.append(criteria(test_target, knn(filtered_features, filtered_train_features, train_target, k)))

plt.figure()
plt.plot(k_axis, criteria_axis)
plt.xlabel('Значение k')
plt.ylabel('Критерий качества')
plt.title('Точность предсказания в зависимости от k')
plt.show()

# %% [markdown]
# #### 6. Выводы

# %% [markdown]
# - KKN на чётных k даёт просадку точности. Это, вероятно, связано с тем, что когда мы имеем одинковое количество соседей с разными значениями признака, mode() округляет предсказание в сторону одного из признаков и даёт ошибочный результат.
# - При увеличении k точность KNN растёт, но при достаточно больших значениях можно наблюдать падение точности.
# - Дерево глубины 2 может превысить точность классификатора KNN. В рамках данной задачи оно экономнее.
# - При увеличении глубины дерева точность предсказаний растёт.
